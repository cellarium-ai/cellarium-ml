# %% [markdown]
# # Identical prompt and query

# %% [markdown]
# Stephen Fleming
#
# 2025.03.26

# %% [markdown]
# The idea is to "snap" a cell to the manifold and see whether the output is similar to the input.

# %% [markdown]
# Use Mehrtash's branch `mb-cellarium-gpt-predict`

# %%
# !gsutil cp gs://cellarium-scratch/cellariumgpt_artifacts/pbmc_benchmark/pbmc_adata.h5ad \
#     /home/sfleming/data/assay_conversion/

# %%
import anndata
import numpy as np
import pandas as pd
import torch
from tqdm import tqdm

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# adata = anndata.read_h5ad('/home/sfleming/data/assay_conversion/pbmc_adata.h5ad')
adata = anndata.read_h5ad('/work/hdd/bbjr/mallina1/data/mb-ml-dev-vm/data/pbmc_adata.h5ad')
adata
# Out:
# /u/mallina1/envs/torch_jax2/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# AnnData object with n_obs × n_vars = 30495 × 33694
#     obs: 'NAME', 'nGene', 'nUMI', 'percent.mito', 'Cluster', 'CellType', 'Experiment', 'Method'
#     var: 'gene_symbols'
#     uns: 'CellType_colors', 'Method_colors'
#     obsm: 'X_harmony'

# %%
from cellarium.ml.utilities.inference.cellarium_gpt_inference import CellariumGPTInferenceContext
# Out:
# 2025-03-26 18:10:46.687714: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-26 18:10:48.048604: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
adata.var
# Out:
#                   gene_symbols
# ENSG00000000003         TSPAN6
# ENSG00000000005           TNMD
# ENSG00000000419           DPM1
# ENSG00000000457          SCYL3
# ENSG00000000460       C1orf112
# ...                        ...
# ENSG00000283096  RP11-157J13.1
# ENSG00000283103  LLNLR-245B6.1
# ENSG00000283117  CTD-2060L22.1
# ENSG00000283118   RP11-107E5.4
# ENSG00000283125   RP11-299P2.2
#
# [33694 rows x 1 columns]

# %%
adata.obs
# Out:
#                                              NAME nGene   nUMI  \
# 0                          pbmc1_Celseq2_1_ACAGAC  3290   9030
# 1                          pbmc1_Celseq2_1_ACAGGA  2797   8482
# 2                          pbmc1_Celseq2_1_ACGTTG  2651   6787
# 3                          pbmc1_Celseq2_1_AGACCA  2766   6004
# 4                          pbmc1_Celseq2_1_CAACTC  3510  10162
# ...                                           ...   ...    ...
# 30490  pbmc2_inDrops_1_TAGTCTCT.GAGCCTTA.ATCCGCTA   453    717
# 30491  pbmc2_inDrops_1_TCCAGAAG.TTATGCGA.TAAGACGG   592    938
# 30492  pbmc2_inDrops_1_TGAATCCT.GAGCCTTA.CCCAAGCA   406    662
# 30493  pbmc2_inDrops_1_TGAATCCT.TTATGCGA.CATCTCCC  1001   2066
# 30494  pbmc2_inDrops_1_TGAGCACA.GAGCCTTA.CGAGTCTG   184    253
#
#              percent.mito Cluster                     CellType Experiment  \
# 0      0.0902547065337763       1                  CD4+ T cell      pbmc1
# 1       0.116953548691346       1                  CD4+ T cell      pbmc1
# 2       0.111978782967438       1                  CD4+ T cell      pbmc1
# 3      0.0932711525649567       1                  CD4+ T cell      pbmc1
# 4        0.11621728006298       1                  CD4+ T cell      pbmc1
# ...                   ...     ...                          ...        ...
# 30490   0.097629009762901      11  Plasmacytoid dendritic cell      pbmc2
# 30491   0.035181236673774      11  Plasmacytoid dendritic cell      pbmc2
# 30492   0.138972809667674      11  Plasmacytoid dendritic cell      pbmc2
# 30493  0.0556631171345595      11  Plasmacytoid dendritic cell      pbmc2
# 30494   0.146245059288538      11  Plasmacytoid dendritic cell      pbmc2
#
#          Method
# 0      CEL-Seq2
# 1      CEL-Seq2
# 2      CEL-Seq2
# 3      CEL-Seq2
# 4      CEL-Seq2
# ...         ...
# 30490   inDrops
# 30491   inDrops
# 30492   inDrops
# 30493   inDrops
# 30494   inDrops
#
# [30495 rows x 8 columns]

# %%
import os 

ROOT_PATH = "/work/hdd/bbjr/mallina1/data/mb-ml-dev-vm"
GENE_INFO_PATH = os.path.join(ROOT_PATH, "gene_info", "gene_info.tsv")
REF_ADATA_FP = '/work/hdd/bbjr/mallina1/data/mb-ml-dev-vm/data/extract_0.h5ad'
CHECKPOINT_PATH = "/work/hdd/bbjr/mallina1/cellarium/models/compute_optimal_checkpoints/epoch=6-step=63560.ckpt"


# ctx = CellariumGPTInferenceContext(
#     cellarium_gpt_ckpt_path='/home/sfleming/trained_models/epoch=1-step=29161.ckpt',
#     ref_adata_path='/home/sfleming/data/extract_0.h5ad',
#     gene_info_tsv_path='/home/sfleming/data/gene_info.tsv',
#     device="cuda",
#     attention_backend="mem_efficient",
#     verbose=True,
# )

ctx = CellariumGPTInferenceContext(
    cellarium_gpt_ckpt_path=CHECKPOINT_PATH,
    ref_adata_path=REF_ADATA_FP,
    gene_info_tsv_path=GENE_INFO_PATH,
    device="cuda",
    attention_backend="mem_efficient",
    verbose=True,
)

# %%
adata_sub = adata[
    (adata.obs['Method'] == '10x Chromium (v3)')
    & (adata.obs['CellType'] == 'CD4+ T cell')
][:, adata.var_names.isin(ctx.model_var_names_set)].copy()
adata_sub.obs['total_mrna_umis'] = adata_sub.obs['nUMI'].astype(int)
adata_sub.obs['assay_ontology_term_id'] = 'EFO:0009922'  # 10x v3
adata_sub.obs['suspension_type'] = 'cell'
adata_sub.obs['cell_type_ontology_term_id'] = 'CL:0000624'  # CD4+ alpha-beta T cell
adata_sub.obs['tissue_ontology_term_id'] = 'UBERON:0000178'  # blood
adata_sub.obs['development_stage_ontology_term_id'] = None
adata_sub.obs['disease_ontology_term_id'] = None
adata_sub.obs['sex_ontology_term_id'] = None
adata_sub
# Out:
# AnnData object with n_obs × n_vars = 960 × 32351
#     obs: 'NAME', 'nGene', 'nUMI', 'percent.mito', 'Cluster', 'CellType', 'Experiment', 'Method', 'total_mrna_umis', 'assay_ontology_term_id', 'suspension_type', 'cell_type_ontology_term_id', 'tissue_ontology_term_id', 'development_stage_ontology_term_id', 'disease_ontology_term_id', 'sex_ontology_term_id'
#     var: 'gene_symbols'
#     uns: 'CellType_colors', 'Method_colors'
#     obsm: 'X_harmony'

# %%
adata_sub.obs.head()
# Out:
#                                NAME nGene  nUMI        percent.mito Cluster  \
# 6697  pbmc1_10x_v3_AAACCCACACTTGGGC  1860  6914  0.0911194677466011       1
# 6698  pbmc1_10x_v3_AAACCCATCTTACACT  1758  6168  0.0856031128404669       1
# 6699  pbmc1_10x_v3_AAAGAACAGCAGGCAT  2425  8265  0.0815486993345433       1
# 6700  pbmc1_10x_v3_AAAGAACTCAAAGACA  1553  5789  0.0730696147866644       1
# 6701  pbmc1_10x_v3_AAAGTCCGTAGGCAGT  2655  9163  0.0966932227436429       1
#
#          CellType Experiment             Method  total_mrna_umis  \
# 6697  CD4+ T cell      pbmc1  10x Chromium (v3)             6914
# 6698  CD4+ T cell      pbmc1  10x Chromium (v3)             6168
# 6699  CD4+ T cell      pbmc1  10x Chromium (v3)             8265
# 6700  CD4+ T cell      pbmc1  10x Chromium (v3)             5789
# 6701  CD4+ T cell      pbmc1  10x Chromium (v3)             9163
#
#      assay_ontology_term_id suspension_type cell_type_ontology_term_id  \
# 6697            EFO:0009922            cell                 CL:0000624
# 6698            EFO:0009922            cell                 CL:0000624
# 6699            EFO:0009922            cell                 CL:0000624
# 6700            EFO:0009922            cell                 CL:0000624
# 6701            EFO:0009922            cell                 CL:0000624
#
#      tissue_ontology_term_id development_stage_ontology_term_id  \
# 6697          UBERON:0000178                               None
# 6698          UBERON:0000178                               None
# 6699          UBERON:0000178                               None
# 6700          UBERON:0000178                               None
# 6701          UBERON:0000178                               None
#
#      disease_ontology_term_id sex_ontology_term_id
# 6697                     None                 None
# 6698                     None                 None
# 6699                     None                 None
# 6700                     None                 None
# 6701                     None                 None

# %%
adata_sub_sub = adata_sub[:, np.random.choice(adata_sub.shape[1], 4096, replace=False)].copy()
adata_sub_sub
# Out:
# AnnData object with n_obs × n_vars = 960 × 4096
#     obs: 'NAME', 'nGene', 'nUMI', 'percent.mito', 'Cluster', 'CellType', 'Experiment', 'Method', 'total_mrna_umis', 'assay_ontology_term_id', 'suspension_type', 'cell_type_ontology_term_id', 'tissue_ontology_term_id', 'development_stage_ontology_term_id', 'disease_ontology_term_id', 'sex_ontology_term_id'
#     var: 'gene_symbols'
#     uns: 'CellType_colors', 'Method_colors'
#     obsm: 'X_harmony'

# %%
def batched_inference_query_equals_prompt_no_metadata(ctx, adata, batch_size: int = 32):

    gene_marginal_mean_nq_list = []

    for ind in tqdm(range(0, len(adata), batch_size)):

        tokens_dict, context_indices = ctx.generate_tokens_from_adata(
            adata=adata,
            obs_index=np.arange(ind, min(len(adata), ind + batch_size)),
            query_var_names=adata.var_names,
            n_rand_prompt_vars=None,
            rand_prompt_var_names_sublist=None,
            fixed_prompt_var_names_sublist=None,
            rng=None,
            query_total_mrna_umis=None,
            metadata_prompt_masks_dict={  # do you want it to show up in the prompt
                "cell_type": False,
                "tissue": False,
                "development_stage": False,
                "disease": False,
                "sex": False,
            },
        )

        with torch.no_grad():
            gene_logits_nqk = ctx.get_gene_value_logits_from_tokens(tokens_dict,
                                                                    context_indices,
                                                                    max_counts=None)
            gene_logits_nqk = gene_logits_nqk.cpu()

            dist = torch.distributions.categorical.Categorical(logits = gene_logits_nqk.squeeze())
            gene_marginal_mean_nq = dist.sample()

            # gene_marginal_mean_nq, _ = ctx.get_marginal_mean_std_from_tokens(
            #     tokens_dict=tokens_dict,
            #     context_indices=context_indices,
            #     use_logsumexp=True,
            #     max_counts=None,
            # )

        gene_marginal_mean_nq_list.append(gene_marginal_mean_nq)

    gene_marginal_mean_nq = torch.cat(gene_marginal_mean_nq_list, dim=0)
    return gene_marginal_mean_nq

# %%
gene_marginal_mean_nq = batched_inference_query_equals_prompt_no_metadata(ctx, adata_sub_sub)
# Out:
#   0%|                                                                                                                   | 0/30 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████| 30/30 [06:09<00:00, 12.33s/it]

# %%
gene_marginal_mean_nq.shape
# Out:
# torch.Size([960, 4096])

# %%
df = pd.DataFrame(
    {
        "raw_mean": np.array(adata_sub_sub.X.mean(axis=0)).squeeze(),
        "gpt_mean": gene_marginal_mean_nq.cpu().numpy().squeeze().mean(axis=0),
    },
    index=adata_sub_sub.var_names,
)
df['raw_mean_norm'] = df['raw_mean'] / df['raw_mean'].sum()
df['gpt_mean_norm'] = df['gpt_mean'] / df['gpt_mean'].sum()
df
# Out:
#                  raw_mean  gpt_mean  raw_mean_norm  gpt_mean_norm
# ENSG00000186710  0.000000  0.001042       0.000000       0.000001
# ENSG00000233970  0.000000  0.000000       0.000000       0.000000
# ENSG00000100626  0.007292  0.000000       0.000011       0.000000
# ENSG00000136273  0.162500  0.134375       0.000249       0.000152
# ENSG00000184454  0.015625  0.005208       0.000024       0.000006
# ...                   ...       ...            ...            ...
# ENSG00000257527  0.000000  0.000000       0.000000       0.000000
# ENSG00000134684  0.175000  0.145833       0.000268       0.000165
# ENSG00000176020  0.000000  0.000000       0.000000       0.000000
# ENSG00000183508  0.428126  0.343750       0.000656       0.000390
# ENSG00000255039  0.000000  0.000000       0.000000       0.000000
#
# [4096 rows x 4 columns]

# %%
plt.figure(figsize=(4, 4))
plt.loglog(df["raw_mean_norm"], df["gpt_mean_norm"], 'k.')
plt.plot([0, 1], [0, 1], 'r:')
plt.gca().axis('equal')
plt.ylim([1e-6, 1e-1])
plt.xlim([1e-6, 1e-1])
plt.xlabel("Raw mean expression")
plt.ylabel("GPT mean expression")
plt.show()

# %%
from scipy.stats import pearsonr

# %%
pearsonr(np.log1p(df["raw_mean_norm"]), np.log1p(df["gpt_mean_norm"]))
# Out:
# PearsonRResult(statistic=0.9608326656926103, pvalue=0.0)
