# %% [markdown]
# # Query the cellxgene census

# %% [markdown]
# Stephen Fleming
#
# 2025.10.08

# %% [markdown]
# Use the conda env `census`

# %% [markdown]
# Pull data from cellxgene programmatically.

# %%
import cellxgene_census
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Dataset info

# %%
with cellxgene_census.open_soma(census_version="2024-07-01") as census:
    info = census["census_info"]["summary"].read().concat().to_pandas()

info
# Out:
#    soma_joinid                       label       value
# 0            0       census_schema_version       2.0.1
# 1            1           census_build_date  2024-05-20
# 2            2      dataset_schema_version       5.0.0
# 3            3            total_cell_count   115556140
# 4            4           unique_cell_count    60597966
# 5            5  number_donors_homo_sapiens       17651
# 6            6  number_donors_mus_musculus        4216

# %%
with cellxgene_census.open_soma() as census:
    info = census["census_info"]["summary_cell_counts"].read().concat().to_pandas()

info[info['category'] == 'all']
# Out:
# The "stable" release is currently 2024-07-01. Specify 'census_version="2024-07-01"' in future calls to open_soma() to ensure data consistency.
#       soma_joinid      organism category label ontology_term_id  \
# 0               0  Homo sapiens      all    na               na
# 1189         1189  Mus musculus      all    na               na
#
#       total_cell_count  unique_cell_count
# 0             74322510           44265932
# 1189          41233630           16332034

# %%
with cellxgene_census.open_soma() as census:
    dataset_df = census["census_info"]["datasets"].read().concat().to_pandas()

dataset_df
# Out:
# The "stable" release is currently 2024-07-01. Specify 'census_version="2024-07-01"' in future calls to open_soma() to ensure data consistency.
#      soma_joinid                                           citation  \
# 0              0  Publication: https://doi.org/10.1002/hep4.1854...
# 1              1  Publication: https://doi.org/10.1126/sciimmuno...
# 2              2  Publication: https://doi.org/10.1038/s41593-02...
# 3              3  Publication: https://doi.org/10.1038/s41467-02...
# 4              4  Publication: https://doi.org/10.1038/s41590-02...
# ..           ...                                                ...
# 807          807  Publication: https://doi.org/10.1038/s41586-02...
# 808          808  Publication: https://doi.org/10.1101/2023.05.0...
# 809          809  Publication: https://doi.org/10.1101/2023.05.0...
# 810          810  Publication: https://doi.org/10.1038/s41586-02...
# 811          811  Publication: https://doi.org/10.1038/s41586-02...
#
#                             collection_id  \
# 0    44531dd9-1388-4416-a117-af0a99de2294
# 1    3a2af25b-2338-4266-aad3-aa8d07473f50
# 2    180bff9c-c8a5-4539-b13b-ddbc00d643e6
# 3    bf325905-5e8e-42e3-933d-9a9053e9af80
# 4    93eebe82-d8c3-41bc-a906-63b5b5f24a9d
# ..                                    ...
# 807  45d5d2c3-bc28-4814-aed6-0bb6f0e11c82
# 808  1ca90a2d-2943-483d-b678-b809bf464c30
# 809  1ca90a2d-2943-483d-b678-b809bf464c30
# 810  45d5d2c3-bc28-4814-aed6-0bb6f0e11c82
# 811  45d5d2c3-bc28-4814-aed6-0bb6f0e11c82
#
#                                        collection_name  \
# 0    Single-Cell, Single-Nucleus, and Spatial RNA S...
# 1    Single-cell analysis of human B cell maturatio...
# 2    Molecular characterization of selectively vuln...
# 3    Single-cell Atlas of common variable immunodef...
# 4    Single-cell proteo-genomic reference maps of t...
# ..                                                 ...
# 807  A single-cell transcriptional timelapse of mou...
# 808  SEA-AD: Seattle Alzheimer’s Disease Brain Cell...
# 809  SEA-AD: Seattle Alzheimer’s Disease Brain Cell...
# 810  A single-cell transcriptional timelapse of mou...
# 811  A single-cell transcriptional timelapse of mou...
#
#                  collection_doi                            dataset_id  \
# 0             10.1002/hep4.1854  0895c838-e550-48a3-a777-dbcd35d30272
# 1    10.1126/sciimmunol.abe6291  00ff600e-6e2e-4d76-846f-0eec4f0ae417
# 2    10.1038/s41593-020-00764-7  bdacc907-7c26-419f-8808-969eab3ca2e8
# 3    10.1038/s41467-022-29450-x  a5d95a42-0137-496f-8a60-101e17f263c8
# 4    10.1038/s41590-021-01059-0  d3566d6a-a455-4a15-980f-45eb29114cab
# ..                          ...                                   ...
# 807  10.1038/s41586-024-07069-w  0bce33ed-455c-4e12-93f8-b7b04a2de4a1
# 808   10.1101/2023.05.08.539485  c2876b1b-06d8-4d96-a56b-5304f815b99a
# 809   10.1101/2023.05.08.539485  6f7fd0f1-a2ed-4ff1-80d3-33dde731cbc3
# 810  10.1038/s41586-024-07069-w  dcfa2614-7ca7-4d82-814c-350626eccb26
# 811  10.1038/s41586-024-07069-w  dcfd4feb-18a3-4b30-81d7-1b0c544a8ab3
#
#                        dataset_version_id  \
# 0    fb76c95f-0391-4fac-9fb9-082ce2430b59
# 1    b6737a5e-9069-4dd6-9a57-92e17a746df9
# 2    0e02290f-b992-450b-8a19-554f73cd7f09
# 3    40832710-d7b1-43fb-b2c2-1cd2255bc3ac
# 4    eb6c070c-ff67-4c1f-8d4d-65f9fe2119ee
# ..                                    ...
# 807  ffeb40f8-d4b9-45c4-95cc-5e2674452ef8
# 808  77dab54a-f2a8-42fc-8c1b-3fda90622ac7
# 809  b0cbf861-edd3-4add-a09a-c8698ed0cedf
# 810  4ef3a829-b36e-413f-9a32-56f5a91b1041
# 811  9da4d19f-f6ac-4bf0-a47e-2935b1164569
#
#                                          dataset_title  \
# 0                         Healthy human liver: B cells
# 1                 Human tonsil nonlymphoid cells scRNA
# 2    Molecular characterization of selectively vuln...
# 3                     Steady-state B cells - scRNA-seq
# 4     blood and bone marrow from a healthy young donor
# ..                                                 ...
# 807                 Whole dataset: Normalized subset 2
# 808  Whole Taxonomy - MTG: Seattle Alzheimer's Dise...
# 809  Whole Taxonomy - DLPFC: Seattle Alzheimer's Di...
# 810                       Major cell cluster: Mesoderm
# 811                     Whole dataset: Raw counts only
#
#                              dataset_h5ad_path  dataset_total_cell_count
# 0    0895c838-e550-48a3-a777-dbcd35d30272.h5ad                       146
# 1    00ff600e-6e2e-4d76-846f-0eec4f0ae417.h5ad                       363
# 2    bdacc907-7c26-419f-8808-969eab3ca2e8.h5ad                      3799
# 3    a5d95a42-0137-496f-8a60-101e17f263c8.h5ad                      1324
# 4    d3566d6a-a455-4a15-980f-45eb29114cab.h5ad                     15502
# ..                                         ...                       ...
# 807  0bce33ed-455c-4e12-93f8-b7b04a2de4a1.h5ad                   2863559
# 808  c2876b1b-06d8-4d96-a56b-5304f815b99a.h5ad                   1226855
# 809  6f7fd0f1-a2ed-4ff1-80d3-33dde731cbc3.h5ad                   1309414
# 810  dcfa2614-7ca7-4d82-814c-350626eccb26.h5ad                   3267338
# 811  dcfd4feb-18a3-4b30-81d7-1b0c544a8ab3.h5ad                  11441407
#
# [812 rows x 10 columns]

# %% [markdown]
# ## Obs

# %%
with cellxgene_census.open_soma() as census:

    # Reads SOMADataFrame as a slice
    cell_metadata = census["census_data"]["homo_sapiens"].obs.read(
        value_filter = f"""(is_primary_data == True)""",
        column_names = ["assay", "cell_type", "cell_type_ontology_term_id", 
                        "tissue", "tissue_ontology_term_id", "dataset_id", "donor_id", 
                        "tissue_general", "suspension_type", 
                        "disease", "disease_ontology_term_id", 
                        "development_stage", "development_stage_ontology_term_id", 
                        "raw_sum",
                        "sex", "soma_joinid"]
    )

    # Concatenates results to pyarrow.Table
    cell_metadata = cell_metadata.concat()

    # Converts to pandas.DataFrame
    cell_metadata = cell_metadata.to_pandas()
# Out:
# The "stable" release is currently 2024-07-01. Specify 'census_version="2024-07-01"' in future calls to open_soma() to ensure data consistency.

# %%
cell_metadata.columns
# Out:
# Index(['assay', 'cell_type', 'cell_type_ontology_term_id', 'tissue',
#        'tissue_ontology_term_id', 'dataset_id', 'donor_id', 'tissue_general',
#        'suspension_type', 'disease', 'disease_ontology_term_id',
#        'development_stage', 'development_stage_ontology_term_id', 'raw_sum',
#        'sex', 'soma_joinid', 'is_primary_data'],
#       dtype='object')

# %%
sorted(cell_metadata.tissue.unique())
# Out:
# ['Brodmann (1909) area 4',
#  'adipose tissue',
#  'adrenal gland',
#  'adrenal tissue',
#  'alveolus of lung',
#  'ampulla of uterine tube',
#  'angular gyrus',
#  'anterior cingulate cortex',
#  'anterior cingulate gyrus',
#  'anterior part of tongue',
#  'anterior wall of left ventricle',
#  'aorta',
#  'apex of heart',
#  'arm skin',
#  'artery',
#  'ascending colon',
#  'axilla',
#  'basal ganglion',
#  'basal zone of heart',
#  'bladder organ',
#  'blood',
#  'body of stomach',
#  'bone marrow',
#  'bone spine',
#  'brain',
#  'brain white matter',
#  'breast',
#  'bronchopulmonary lymph node',
#  'bronchus',
#  'caecum',
#  'caecum epithelium',
#  'cardia of stomach',
#  'cardiac atrium',
#  'cardiac ventricle',
#  'caudal ganglionic eminence',
#  'caudate lobe of liver',
#  'caudate nucleus',
#  'cerebellar cortex',
#  'cerebellum',
#  'cerebellum vermis lobule',
#  'cerebral cortex',
#  'cerebral nuclei',
#  'cervical lymph node',
#  'cervical spinal cord white matter',
#  'chorionic villus',
#  'choroid plexus',
#  'ciliary body',
#  'cingulate cortex',
#  'colon',
#  'colonic epithelium',
#  'conjunctiva',
#  'cornea',
#  'corneo-scleral junction',
#  'coronary artery',
#  'cortex of kidney',
#  'decidua',
#  'decidua basalis',
#  'dentate nucleus',
#  'dermis',
#  'descending colon',
#  'dorsolateral prefrontal cortex',
#  'duodeno-jejunal junction',
#  'duodenum',
#  'endocrine pancreas',
#  'endometrium',
#  'entorhinal cortex',
#  'epithelium of esophagus',
#  'epithelium of small intestine',
#  'epithelium of trachea',
#  'esophagogastric junction',
#  'esophagus',
#  'esophagus muscularis mucosa',
#  'exocrine pancreas',
#  'eye',
#  'eye trabecular meshwork',
#  'fallopian tube',
#  'fimbria of uterine tube',
#  'forebrain',
#  'fovea centralis',
#  'frontal cortex',
#  'frontal lobe',
#  'gallbladder',
#  'ganglionic eminence',
#  'gastrocnemius',
#  'gingiva',
#  'gonad',
#  'heart',
#  'heart left ventricle',
#  'heart right ventricle',
#  'hemisphere part of cerebellar posterior lobe',
#  'hepatic cecum',
#  'hepatic flexure of colon',
#  'hindgut',
#  'hindlimb skin',
#  'hippocampal formation',
#  'hypothalamus',
#  'ileal epithelium',
#  'ileum',
#  'inguinal lymph node',
#  'insular cortex',
#  'interventricular septum',
#  'intestine',
#  'iris',
#  'islet of Langerhans',
#  'isthmus of fallopian tube',
#  'jejunal epithelium',
#  'jejunum',
#  'kidney',
#  'kidney blood vessel',
#  'lacrimal gland',
#  'lamina propria',
#  'lamina propria of large intestine',
#  'lamina propria of mucosa of colon',
#  'lamina propria of small intestine',
#  'large intestine',
#  'lateral ganglionic eminence',
#  'left cardiac atrium',
#  'left colon',
#  'left frontal lobe',
#  'left lung',
#  'left parietal lobe',
#  'left temporal lobe',
#  'lens of camera-type eye',
#  'lingula of left lung',
#  'liver',
#  'lower esophagus',
#  'lower leg skin',
#  'lower lobe of left lung',
#  'lower lobe of right lung',
#  'lung',
#  'lung parenchyma',
#  'lymph node',
#  'macula lutea',
#  'macula lutea proper',
#  'mammary gland',
#  'medial ganglionic eminence',
#  'medial orbital frontal cortex',
#  'mesenteric artery',
#  'mesenteric lymph node',
#  'midbrain',
#  'middle lobe of right lung',
#  'middle temporal gyrus',
#  'mucosa',
#  'muscle of abdomen',
#  'muscle of pelvic diaphragm',
#  'muscle organ',
#  'muscle tissue',
#  'myelencephalon',
#  'myometrium',
#  'nasal cavity',
#  'nasopharynx',
#  'neural tube',
#  'nose',
#  'nose skin',
#  'occipital cortex',
#  'occipital lobe',
#  'omental fat pad',
#  'omentum',
#  'orbitofrontal cortex',
#  'ovary',
#  'pancreas',
#  'parietal cortex',
#  'parietal lobe',
#  'parotid gland',
#  'perifoveal part of retina',
#  'peripheral region of retina',
#  'peripheral zone of prostate',
#  'perirenal fat',
#  'pigment epithelium of eye',
#  'placenta',
#  'pleura',
#  'pleural effusion',
#  'pons',
#  'posterior part of tongue',
#  'prefrontal cortex',
#  'primary auditory cortex',
#  'primary motor cortex',
#  'primary somatosensory cortex',
#  'primary visual cortex',
#  'prostate gland',
#  'putamen',
#  'pyloric antrum',
#  'rectum',
#  'rectus abdominis muscle',
#  'renal medulla',
#  'renal papilla',
#  'renal pelvis',
#  'respiratory airway',
#  'retina',
#  'retinal neural layer',
#  'rib',
#  'right cardiac atrium',
#  'right colon',
#  'right frontal lobe',
#  'right lung',
#  'right occipital lobe',
#  'right parietal lobe',
#  'right temporal lobe',
#  'saliva',
#  'scalp',
#  'sclera',
#  'sigmoid colon',
#  'skeletal muscle tissue',
#  'skin epidermis',
#  'skin of abdomen',
#  'skin of back',
#  'skin of body',
#  'skin of cheek',
#  'skin of chest',
#  'skin of external ear',
#  'skin of face',
#  'skin of forearm',
#  'skin of forehead',
#  'skin of hip',
#  'skin of leg',
#  'skin of pes',
#  'skin of prepuce of penis',
#  'skin of scalp',
#  'skin of shoulder',
#  'skin of temple',
#  'skin of trunk',
#  'small intestine',
#  'spinal cord',
#  'spleen',
#  'stomach',
#  'subcutaneous abdominal adipose tissue',
#  'subcutaneous adipose tissue',
#  'sublingual gland',
#  'submucosa of ascending colon',
#  'submucosa of ileum',
#  'submucosal esophageal gland',
#  'substantia nigra pars compacta',
#  'superior frontal gyrus',
#  'telencephalon',
#  'temporal cortex',
#  'temporal lobe',
#  'temporoparietal junction',
#  'tendon of semitendinosus',
#  'testis',
#  'thalamic complex',
#  'thoracic lymph node',
#  'thymus',
#  'thyroid gland',
#  'tongue',
#  'tonsil',
#  'trachea',
#  'transition zone of prostate',
#  'transverse colon',
#  'umbilical cord blood',
#  'upper lobe of left lung',
#  'upper lobe of right lung',
#  'upper outer quadrant of breast',
#  'ureter',
#  'uterine cervix',
#  'uterus',
#  'vasculature',
#  'vault of skull',
#  'vein',
#  'venous blood',
#  'vermiform appendix',
#  'visceral abdominal adipose tissue',
#  'white matter of cerebellum',
#  'yolk sac',
#  'zone of skin']

# %% [markdown]
# ### Cell types per donor

# %%
cell_metadata[['cell_type', 'cell_type_ontology_term_id']].drop_duplicates().head()
# Out:
#                          cell_type cell_type_ontology_term_id
# 0                     naive B cell                 CL:0000788
# 5         unswitched memory B cell                 CL:0000970
# 14    class switched memory B cell                 CL:0000972
# 1324                   plasma cell                 CL:0000786
# 1329     erythroid progenitor cell                 CL:0000038

# %%
cell_metadata['cell_type_unknown'] = cell_metadata['cell_type'] == 'unknown'

# %%
cell_metadata['cell_type_unknown'].sum() / len(cell_metadata)
# Out:
# 0.02986755141629007

# %%
donor_cell_type_df1 = (
    cell_metadata[['dataset_id', 'donor_id', 'cell_type']]
    .groupby(['dataset_id', 'donor_id'], observed=True)
    .agg(lambda s: s.nunique())
).rename(columns={'cell_type': 'n_unique_cell_types'})


donor_cell_type_df2 = (
    cell_metadata[['dataset_id', 'donor_id', 'cell_type_unknown']]
    .groupby(['dataset_id', 'donor_id'], observed=True)
    .mean()
).rename(columns={'cell_type_unknown': 'cell_type_unknown_fraction'})



donor_cell_type_df = pd.concat([donor_cell_type_df1, donor_cell_type_df2], axis=1)

# %%
donor_cell_type_df
# Out:
#                                                  n_unique_cell_types  \
# dataset_id                           donor_id
# 00476f9f-ebc1-4b72-b541-32f912ce36ea H19.30.001                   11
# 01209dce-3575-4bed-b1df-129f57fbc031 Donor1                        6
#                                      Donor2                        6
#                                      DonorA                        4
#                                      DonorB                        4
# ...                                                              ...
# fe4b89d5-461e-440c-a5a8-621b37b122c0 195045                        8
#                                      199129                        8
# ff7d15fa-f4b6-4a0e-992e-fd0c9d088ded H18.30.002                    9
#                                      H19.30.001                    8
#                                      H19.30.002                   10
#
#                                                  cell_type_unknown_fraction
# dataset_id                           donor_id
# 00476f9f-ebc1-4b72-b541-32f912ce36ea H19.30.001                         0.0
# 01209dce-3575-4bed-b1df-129f57fbc031 Donor1                             0.0
#                                      Donor2                             0.0
#                                      DonorA                             0.0
#                                      DonorB                             0.0
# ...                                                                     ...
# fe4b89d5-461e-440c-a5a8-621b37b122c0 195045                             0.0
#                                      199129                             0.0
# ff7d15fa-f4b6-4a0e-992e-fd0c9d088ded H18.30.002                         0.0
#                                      H19.30.001                         0.0
#                                      H19.30.002                         0.0
#
# [7305 rows x 2 columns]

# %%
donor_cell_type_df.sort_values('cell_type_unknown_fraction', ascending=False).head()
# Out:
#                                                n_unique_cell_types  \
# dataset_id                           donor_id
# 7bb64315-9e5a-41b9-9235-59acf9642a3e NGCII511                    1
#                                      NGCII545                    1
#                                      NGCII529                    1
#                                      NGCII533                    1
#                                      NGCII536                    1
#
#                                                cell_type_unknown_fraction
# dataset_id                           donor_id
# 7bb64315-9e5a-41b9-9235-59acf9642a3e NGCII511                         1.0
#                                      NGCII545                         1.0
#                                      NGCII529                         1.0
#                                      NGCII533                         1.0
#                                      NGCII536                         1.0

# %%
# how many (datasets, donors) have zero cell_type annotations?

donor_cell_type_df[donor_cell_type_df['cell_type_unknown_fraction'] == 1]
# Out:
#                                                n_unique_cell_types  \
# dataset_id                           donor_id
# 0c9a8cfb-6649-4d52-b418-6d8e56bd7afe C66                         1
# 7bb64315-9e5a-41b9-9235-59acf9642a3e NGCII498                    1
#                                      NGCII499                    1
#                                      NGCII502                    1
#                                      NGCII509                    1
#                                      NGCII510                    1
#                                      NGCII511                    1
#                                      NGCII512                    1
#                                      NGCII513                    1
#                                      NGCII514                    1
#                                      NGCII518                    1
#                                      NGCII519                    1
#                                      NGCII520                    1
#                                      NGCII521                    1
#                                      NGCII522                    1
#                                      NGCII524                    1
#                                      NGCII525                    1
#                                      NGCII527                    1
#                                      NGCII529                    1
#                                      NGCII531                    1
#                                      NGCII533                    1
#                                      NGCII536                    1
#                                      NGCII538                    1
#                                      NGCII539                    1
#                                      NGCII540                    1
#                                      NGCII541                    1
#                                      NGCII543                    1
#                                      NGCII545                    1
# dea1aa78-c0a2-413f-b375-f91cce49e4d0 3298                        1
#                                      3322                        1
#                                      3345                        1
#                                      3346                        1
#                                      3482                        1
#                                      4956                        1
#                                      5610                        1
#                                      6173                        1
#
#                                                cell_type_unknown_fraction
# dataset_id                           donor_id
# 0c9a8cfb-6649-4d52-b418-6d8e56bd7afe C66                              1.0
# 7bb64315-9e5a-41b9-9235-59acf9642a3e NGCII498                         1.0
#                                      NGCII499                         1.0
#                                      NGCII502                         1.0
#                                      NGCII509                         1.0
#                                      NGCII510                         1.0
#                                      NGCII511                         1.0
#                                      NGCII512                         1.0
#                                      NGCII513                         1.0
#                                      NGCII514                         1.0
#                                      NGCII518                         1.0
#                                      NGCII519                         1.0
#                                      NGCII520                         1.0
#                                      NGCII521                         1.0
#                                      NGCII522                         1.0
#                                      NGCII524                         1.0
#                                      NGCII525                         1.0
#                                      NGCII527                         1.0
#                                      NGCII529                         1.0
#                                      NGCII531                         1.0
#                                      NGCII533                         1.0
#                                      NGCII536                         1.0
#                                      NGCII538                         1.0
#                                      NGCII539                         1.0
#                                      NGCII540                         1.0
#                                      NGCII541                         1.0
#                                      NGCII543                         1.0
#                                      NGCII545                         1.0
# dea1aa78-c0a2-413f-b375-f91cce49e4d0 3298                             1.0
#                                      3322                             1.0
#                                      3345                             1.0
#                                      3346                             1.0
#                                      3482                             1.0
#                                      4956                             1.0
#                                      5610                             1.0
#                                      6173                             1.0

# %%
dataset_df[dataset_df['dataset_id'].isin(
    donor_cell_type_df[donor_cell_type_df['cell_type_unknown_fraction'] == 1].reset_index()['dataset_id']
)]
# Out:
#      soma_joinid                                           citation  \
# 11            11  Publication: https://doi.org/10.1016/j.jhep.20...
# 548          548  Publication: https://doi.org/10.1038/s41593-02...
# 711          711  Publication: https://doi.org/10.1158/2159-8290...
#
#                             collection_id  \
# 11   0c8a364b-97b5-4cc8-a593-23c38c6f0ac5
# 548  b0f0b447-ac37-45b0-b1bf-5c0b7d871120
# 711  a18474f4-ff1e-4864-af69-270b956cee5b
#
#                                        collection_name  \
# 11   Single-cell and spatial transcriptomics charac...
# 548  Single-cell genomic profiling of human dopamin...
# 711  Single-cell RNA sequencing unifies development...
#
#                    collection_doi                            dataset_id  \
# 11     10.1016/j.jhep.2023.12.023  0c9a8cfb-6649-4d52-b418-6d8e56bd7afe
# 548    10.1038/s41593-022-01061-1  dea1aa78-c0a2-413f-b375-f91cce49e4d0
# 711  10.1158/2159-8290.cd-22-0824  7bb64315-9e5a-41b9-9235-59acf9642a3e
#
#                        dataset_version_id  \
# 11   6ff309fa-e9f6-405d-b24e-3c35528f154e
# 548  51affad7-08ed-43b3-93ad-56640f4b8910
# 711  9ec33c56-14a4-4815-b747-34ee38c850e8
#
#                                          dataset_title  \
# 11   Cholangiocytes from human healthy donor liver ...
# 548           Human Nurr-Negative Nuclei 10x scRNA-seq
# 711                    UMAP of Cancer Data integration
#
#                              dataset_h5ad_path  dataset_total_cell_count
# 11   0c9a8cfb-6649-4d52-b418-6d8e56bd7afe.h5ad                      1011
# 548  dea1aa78-c0a2-413f-b375-f91cce49e4d0.h5ad                    104097
# 711  7bb64315-9e5a-41b9-9235-59acf9642a3e.h5ad                    293823

# %% [markdown]
# ### Number of cells

# %%
num_cell_df = (
    cell_metadata[['dataset_id', 'donor_id', 'cell_type']]
    .groupby(['dataset_id', 'donor_id'], observed=True)
    .count()
).rename(columns={'cell_type': 'n_cells'})
num_cell_df
# Out:
#                                                  n_cells
# dataset_id                           donor_id
# 00476f9f-ebc1-4b72-b541-32f912ce36ea H19.30.001    10099
# 01209dce-3575-4bed-b1df-129f57fbc031 Donor1        16185
#                                      Donor2        18066
#                                      DonorA         9193
#                                      DonorB         8432
# ...                                                  ...
# fe4b89d5-461e-440c-a5a8-621b37b122c0 195045         1864
#                                      199129         1101
# ff7d15fa-f4b6-4a0e-992e-fd0c9d088ded H18.30.002     5728
#                                      H19.30.001     9766
#                                      H19.30.002    12557
#
# [7305 rows x 1 columns]

# %% [markdown]
# ### Tissue

# %%
tissue_coarsener = np.load('../data/pseudobulk/tissue_coarsen_map.npy', allow_pickle=True).item()

{k: v for i, (k, v) in enumerate({a: b for a, b in tissue_coarsener.items() if b is not None}.items()) if i < 5}
# Out:
# {'UBERON_0000115': 'UBERON_0002048',
#  'UBERON_0001264': 'UBERON_0001264',
#  'UBERON_0002129': 'UBERON_0000955',
#  'UBERON_0000006': 'UBERON_0001264',
#  'UBERON_0002512': 'UBERON_0000992'}

# %%
tissue_dist = np.load('../data/pseudobulk/tissue_distances_from_root.npy', allow_pickle=True).item()
{k: v for i, (k, v) in enumerate(tissue_dist.items()) if i < 5}
# Out:
# {'UBERON_0000061': 2,
#  'UBERON_0000122': 4,
#  'UBERON_0000465': 1,
#  'UBERON_0001637': 6,
#  'UBERON_0001638': 6}

# %%
tissue_coarsener = pd.read_csv("../data/pseudobulk/uberon_ontology_map.tsv",sep="\t",skiprows=1)
tissue_coarsener_dict = dict(zip(tissue_coarsener.iloc[:,1],tissue_coarsener.iloc[:,0]))
tissue_coarsener_dict_reverse = dict(zip(tissue_coarsener.iloc[:,1],tissue_coarsener.iloc[:,0]))

cell_metadata['tissue_coarse_ontology_id'] = cell_metadata['tissue_ontology_term_id'].map(tissue_coarsener_dict)

# %%
tissue_name_lookup = np.load('../data/pseudobulk/tissue_name_lookup.npy', allow_pickle=True).item()
print(tissue_name_lookup)
#{k: v for i, (k, v) in enumerate(tissue_name_lookup.items()) if i < 5}
# Out:
# {'UBERON_0000061': 'anatomical structure', 'UBERON_0000122': 'neuron projection bundle', 'UBERON_0000465': 'material anatomical entity', 'UBERON_0001637': 'artery', 'UBERON_0001638': 'vein', 'UBERON_0010000': 'multicellular anatomical structure', 'UBERON_0001062': 'anatomical entity', 'UBERON_0000475': 'organism subdivision', 'UBERON_0010912': 'subdivision of skeleton', 'UBERON_0004111': 'anatomical conduit', 'UBERON_0000463': 'organism substance', 'UBERON_0001017': 'central nervous system', 'UBERON_0002418': 'cartilage tissue', 'UBERON_0005176': 'tooth enamel organ', 'UBERON_0001763': 'odontogenic papilla', 'UBERON_0001752': 'enamel', 'UBERON_0001751': 'dentine', 'UBERON_0001753': 'cementum', 'UBERON_0008883': 'osteoid', 'UBERON_0000483': 'epithelium', 'UBERON_0000058': 'duct', 'UBERON_0004638': 'blood vessel endothelium', 'UBERON_0000179': 'haemolymphatic fluid', 'UBERON_0002048': 'lung', 'UBERON_0000115': 'lung epithelium', 'UBERON_0001264': 'pancreas', 'UBERON_0001281': 'hepatic sinusoid', 'UBERON_0001474': 'bone element', 'UBERON_0002410': 'autonomic nervous system', 'UBERON_0002129': 'cerebellar cortex', 'UBERON_0001040': 'yolk sac', 'UBERON_0001985': 'corneal endothelium', 'UBERON_0002481': 'bone tissue', 'UBERON_0006799': 'glandular epithelium', 'UBERON_0002365': 'exocrine gland', 'UBERON_0001009': 'circulatory system', 'UBERON_0000949': 'endocrine system', 'UBERON_0000006': 'islet of Langerhans', 'UBERON_0002512': 'corpus luteum', 'UBERON_0005212': 'Leydig cell region of testis', 'UBERON_0002107': 'liver', 'UBERON_0001134': 'skeletal muscle tissue', 'UBERON_0001032': 'sensory system', 'UBERON_0005725': 'olfactory system', 'UBERON_0002217': 'synovial joint', 'UBERON_0001343': 'seminiferous tubule of testis', 'UBERON_0000924': 'ectoderm', 'UBERON_0000926': 'mesoderm', 'UBERON_0000925': 'endoderm', 'UBERON_0002025': 'stratum basale of epidermis', 'UBERON_0000970': 'eye', 'UBERON_0003126': 'trachea', 'UBERON_0001003': 'skin epidermis', 'UBERON_0001817': 'lacrimal gland', 'UBERON_0001821': 'sebaceous gland', 'UBERON_0004821': 'pulmonary alveolus epithelium', 'UBERON_0001236': 'adrenal medulla', 'UBERON_0000412': 'dermal papilla', 'UBERON_0001773': 'sclera', 'UBERON_0001776': 'optic choroid', 'UBERON_0000478': 'extraembryonic structure', 'UBERON_0010302': 'amnioserosa', 'UBERON_0000358': 'blastocyst', 'UBERON_0004590': 'sphincter muscle', 'UBERON_0002049': 'vasculature', 'UBERON_0000085': 'morula', 'UBERON_0004734': 'gastrula', 'UBERON_0007376': 'outer epithelium', 'UBERON_0001038': 'chordotonal organ', 'UBERON_0000043': 'tendon', 'UBERON_0000045': 'ganglion', 'UBERON_0000939': 'imaginal disc', 'UBERON_0000996': 'vagina', 'UBERON_0001347': 'white adipose tissue', 'UBERON_0001348': 'brown adipose tissue', 'UBERON_0002384': 'connective tissue', 'UBERON_0001961': 'mucosa-associated lymphoid tissue', 'UBERON_0001305': 'ovarian follicle', 'UBERON_0004997': 'mucosa of pyloric antrum', 'UBERON_0001983': 'crypt of Lieberkuhn', 'UBERON_0001133': 'cardiac muscle tissue', 'UBERON_0000371': 'syncytiotrophoblast', 'UBERON_0002371': 'bone marrow', 'UBERON_0000966': 'retina', 'UBERON_0001747': 'parenchyma of thyroid gland', 'UBERON_0001772': 'corneal epithelium', 'UBERON_0004786': 'gastrointestinal system mucosa', 'UBERON_0001179': 'peritoneal cavity', 'UBERON_0002299': 'alveolus of lung', 'UBERON_0009842': 'glandular acinus', 'UBERON_0005378': 'olfactory bulb granule cell layer', 'UBERON_0002196': 'adenohypophysis', 'UBERON_0006964': 'pars distalis of adenohypophysis', 'UBERON_0002198': 'neurohypophysis', 'UBERON_0002113': 'kidney', 'UBERON_0002026': 'stratum spinosum of epidermis', 'UBERON_0001905': 'pineal body', 'UBERON_0005751': 'glomerular visceral epithelium', 'UBERON_0000922': 'embryo', 'UBERON_0001058': 'mushroom body', 'UBERON_0001277': 'intestinal epithelium', 'UBERON_0003929': 'digestive tract epithelium', 'UBERON_0000971': 'ommatidium', 'UBERON_0010403': 'brain marginal zone', 'UBERON_0001886': 'choroid plexus', 'UBERON_00032 ...

# %%
# list all the "coarse" tissues: the organs

[tissue_name_lookup.get(t) for t in np.unique(list({a: b for a, b in tissue_coarsener.items() if b is not None}.values()))]
# Out:
# ['nose',
#  'lymph node',
#  'intestine',
#  'blood',
#  'breast',
#  'stomach',
#  'heart',
#  'brain',
#  'eye',
#  'ovary',
#  'uterus',
#  'adipose tissue',
#  'esophagus',
#  'pancreas',
#  'tongue',
#  'placenta',
#  'thyroid gland',
#  'lung',
#  'skin of body',
#  'spleen',
#  'liver',
#  'gallbladder',
#  'kidney',
#  'spinal cord',
#  'thymus',
#  'bone marrow',
#  'fallopian tube',
#  'bladder organ']

# %%
cell_metadata['tissue_coarse_ontology_id'] = cell_metadata['tissue_ontology_term_id'].str.replace(':', '_').map(tissue_coarsener)
cell_metadata['tissue_coarse'] = cell_metadata['tissue_coarse_ontology_id'].map(tissue_name_lookup)

cell_metadata['tissue_name_ont_coarsename_coarseont'] = list(zip(
    cell_metadata['tissue'], 
    cell_metadata['tissue_ontology_term_id'],
    cell_metadata['tissue_coarse'],
    cell_metadata['tissue_coarse_ontology_id'],
))

tissue_df = (
    cell_metadata[['dataset_id', 'donor_id', 'tissue_name_ont_coarsename_coarseont']]
    .groupby(['dataset_id', 'donor_id'], observed=True)
    .agg(lambda s: s.unique().tolist())
)
tissue_df['n_tissues'] = tissue_df['tissue_name_ont_coarsename_coarseont'].apply(len)
tissue_df
# Out:
#                                                               tissue_name_ont_coarsename_coarseont  \
# dataset_id                           donor_id
# 00476f9f-ebc1-4b72-b541-32f912ce36ea H19.30.001  [(hypothalamus, UBERON:0001898, brain, UBERON_...
# 01209dce-3575-4bed-b1df-129f57fbc031 Donor1      [(lower lobe of left lung, UBERON:0008953, lun...
#                                      Donor2      [(lower lobe of left lung, UBERON:0008953, lun...
#                                      DonorA      [(venous blood, UBERON:0013756, blood, UBERON_...
#                                      DonorB      [(venous blood, UBERON:0013756, blood, UBERON_...
# ...                                                                                            ...
# fe4b89d5-461e-440c-a5a8-621b37b122c0 195045      [(ileal epithelium, UBERON:0008345, intestine,...
#                                      199129      [(ileum, UBERON:0002116, intestine, UBERON_000...
# ff7d15fa-f4b6-4a0e-992e-fd0c9d088ded H18.30.002  [(cerebral cortex, UBERON:0000956, brain, UBER...
#                                      H19.30.001  [(cerebral cortex, UBERON:0000956, brain, UBER...
#                                      H19.30.002  [(cerebral cortex, UBERON:0000956, brain, UBER...
#
#                                                  n_tissues
# dataset_id                           donor_id
# 00476f9f-ebc1-4b72-b541-32f912ce36ea H19.30.001          1
# 01209dce-3575-4bed-b1df-129f57fbc031 Donor1              3
#                                      Donor2              3
#                                      DonorA              1
#                                      DonorB              1
# ...                                                    ...
# fe4b89d5-461e-440c-a5a8-621b37b122c0 195045              2
#                                      199129              1
# ff7d15fa-f4b6-4a0e-992e-fd0c9d088ded H18.30.002          1
#                                      H19.30.001          1
#                                      H19.30.002          1
#
# [7305 rows x 2 columns]

# %% [markdown]
# ### Development stage

# %%
devstage_coarsener = np.load('../data/pseudobulk/devstage_coarsen_map.npy', allow_pickle=True).item()
{k: v for i, (k, v) in enumerate({a: b for a, b in devstage_coarsener.items() if b is not None}.items()) if i < 5}
# Out:
# {'HsapDv_0000002': 'HsapDv_0000002',
#  'HsapDv_0000003': 'HsapDv_0000002',
#  'HsapDv_0000005': 'HsapDv_0000002',
#  'HsapDv_0000006': 'HsapDv_0000002',
#  'HsapDv_0000007': 'HsapDv_0000002'}

# %%
devstage_name_lookup = np.load('../data/pseudobulk/devstage_name_lookup.npy', allow_pickle=True).item()
{k: v for i, (k, v) in enumerate(devstage_name_lookup.items()) if i < 5}
# Out:
# {'HsapDv_0000000': 'life cycle stage',
#  'HsapDv_0000001': 'life cycle',
#  'HsapDv_0000002': 'embryonic stage',
#  'HsapDv_0000045': 'prenatal stage',
#  'HsapDv_0000003': 'Carnegie stage 01'}

# %%
# list all the "coarse" tissues: the organs

[devstage_name_lookup.get(t) for t in np.unique(list({a: b for a, b in devstage_coarsener.items() if b is not None}.values()))]
# Out:
# ['embryonic stage',
#  'fetal stage',
#  '80 year-old and over stage',
#  'pediatric stage',
#  'young adult stage',
#  'middle aged stage',
#  '60-79 year-old stage']

# %%
cell_metadata.columns
# Out:
# Index(['assay', 'cell_type', 'cell_type_ontology_term_id', 'tissue',
#        'tissue_ontology_term_id', 'dataset_id', 'donor_id', 'tissue_general',
#        'suspension_type', 'disease', 'disease_ontology_term_id',
#        'development_stage', 'development_stage_ontology_term_id', 'raw_sum',
#        'sex', 'soma_joinid', 'is_primary_data', 'cell_type_unknown',
#        'tissue_coarse_ontology_id', 'tissue_coarse',
#        'tissue_name_ont_coarsename_coarseont'],
#       dtype='object')

# %%
cell_metadata['coarse_development_stage_ontology_id'] = cell_metadata['development_stage_ontology_term_id'].str.replace(':', '_').map(devstage_coarsener)
cell_metadata['coarse_development_stage'] = cell_metadata['coarse_development_stage_ontology_id'].map(devstage_name_lookup)

development_df = (
    cell_metadata[['dataset_id', 'donor_id', 'development_stage', 'development_stage_ontology_term_id', 
                   'coarse_development_stage', 'coarse_development_stage_ontology_id']]
    .groupby(['dataset_id', 'donor_id'], observed=True)
    .agg(lambda s: s.unique().tolist()[0])
)
development_df
# Out:
#                                                           development_stage  \
# dataset_id                           donor_id
# 00476f9f-ebc1-4b72-b541-32f912ce36ea H19.30.001     42-year-old human stage
# 01209dce-3575-4bed-b1df-129f57fbc031 Donor1         65-year-old human stage
#                                      Donor2         52-year-old human stage
#                                      DonorA                         unknown
#                                      DonorB                         unknown
# ...                                                                     ...
# fe4b89d5-461e-440c-a5a8-621b37b122c0 195045      seventh decade human stage
#                                      199129       eighth decade human stage
# ff7d15fa-f4b6-4a0e-992e-fd0c9d088ded H18.30.002     50-year-old human stage
#                                      H19.30.001     42-year-old human stage
#                                      H19.30.002     29-year-old human stage
#
#                                                 development_stage_ontology_term_id  \
# dataset_id                           donor_id
# 00476f9f-ebc1-4b72-b541-32f912ce36ea H19.30.001                     HsapDv:0000136
# 01209dce-3575-4bed-b1df-129f57fbc031 Donor1                         HsapDv:0000159
#                                      Donor2                         HsapDv:0000146
#                                      DonorA                                unknown
#                                      DonorB                                unknown
# ...                                                                            ...
# fe4b89d5-461e-440c-a5a8-621b37b122c0 195045                         HsapDv:0000241
#                                      199129                         HsapDv:0000242
# ff7d15fa-f4b6-4a0e-992e-fd0c9d088ded H18.30.002                     HsapDv:0000144
#                                      H19.30.001                     HsapDv:0000136
#                                      H19.30.002                     HsapDv:0000123
#
#                                                 coarse_development_stage  \
# dataset_id                           donor_id
# 00476f9f-ebc1-4b72-b541-32f912ce36ea H19.30.001        middle aged stage
# 01209dce-3575-4bed-b1df-129f57fbc031 Donor1         60-79 year-old stage
#                                      Donor2            middle aged stage
#                                      DonorA                          NaN
#                                      DonorB                          NaN
# ...                                                                  ...
# fe4b89d5-461e-440c-a5a8-621b37b122c0 195045         60-79 year-old stage
#                                      199129         60-79 year-old stage
# ff7d15fa-f4b6-4a0e-992e-fd0c9d088ded H18.30.002        middle aged stage
#                                      H19.30.001        middle aged stage
#                                      H19.30.002        young adult stage
#
#                                                 coarse_development_stage_ontology_id
# dataset_id                           donor_id
# 00476f9f-ebc1-4b72-b541-32f912ce36ea H19.30.001                       HsapDv_0000267
# 01209dce-3575-4bed-b1df-129f57fbc031 Donor1                           HsapDv_0000272
#                                      Donor2                           HsapDv_0000267
#                                      DonorA                                      NaN
#                                      DonorB                                      NaN
# ...                                                                              ...
# fe4b89d5-461e-440c-a5a8-621b37b122c0 195045                           HsapDv_0000272
#                                      199129                           HsapDv_0000272
# ff7d15fa-f4b6-4a0e-992e-fd0c9d088ded H18.30.002                       HsapDv_0000267
#                                      H19.30.001                       HsapDv_0000267
#                                      H19.30.002                       HsapDv_0000266
#
# [7305 rows x 4 columns]

# %%
vc = development_df[development_df['coarse_development_stage'].isnull()]['development_stage'].value_counts()
vc[vc > 0]
# Out:
# development_stage
# unknown              608
# human adult stage    310
# mature stage         147
# human aged stage      16
# Name: count, dtype: int64

# %% [markdown]
# ### Disease

# %%
disease_df = (
    cell_metadata[['dataset_id', 'donor_id', 'disease', 'disease_ontology_term_id']]
    .groupby(['dataset_id', 'donor_id'], observed=True)
    .agg(lambda s: s.unique().tolist()[0])
)
disease_df
# Out:
#                                                        disease  \
# dataset_id                           donor_id
# 00476f9f-ebc1-4b72-b541-32f912ce36ea H19.30.001         normal
# 01209dce-3575-4bed-b1df-129f57fbc031 Donor1             normal
#                                      Donor2             normal
#                                      DonorA             normal
#                                      DonorB             normal
# ...                                                        ...
# fe4b89d5-461e-440c-a5a8-621b37b122c0 195045      Crohn disease
#                                      199129             normal
# ff7d15fa-f4b6-4a0e-992e-fd0c9d088ded H18.30.002         normal
#                                      H19.30.001         normal
#                                      H19.30.002         normal
#
#                                                 disease_ontology_term_id
# dataset_id                           donor_id
# 00476f9f-ebc1-4b72-b541-32f912ce36ea H19.30.001             PATO:0000461
# 01209dce-3575-4bed-b1df-129f57fbc031 Donor1                 PATO:0000461
#                                      Donor2                 PATO:0000461
#                                      DonorA                 PATO:0000461
#                                      DonorB                 PATO:0000461
# ...                                                                  ...
# fe4b89d5-461e-440c-a5a8-621b37b122c0 195045                MONDO:0005011
#                                      199129                 PATO:0000461
# ff7d15fa-f4b6-4a0e-992e-fd0c9d088ded H18.30.002             PATO:0000461
#                                      H19.30.001             PATO:0000461
#                                      H19.30.002             PATO:0000461
#
# [7305 rows x 2 columns]

# %% [markdown]
# ## Sex

# %%
sex_df = (
    cell_metadata[['dataset_id', 'donor_id', 'sex']]
    .groupby(['dataset_id', 'donor_id'], observed=True)
    .agg(lambda s: s.unique().tolist()[0])
)

# %% [markdown]
# ## Merged table

# %%
cell_metadata.columns
# Out:
# Index(['assay', 'cell_type', 'cell_type_ontology_term_id', 'tissue',
#        'tissue_ontology_term_id', 'dataset_id', 'donor_id', 'tissue_general',
#        'suspension_type', 'disease', 'disease_ontology_term_id',
#        'development_stage', 'development_stage_ontology_term_id', 'raw_sum',
#        'sex', 'soma_joinid', 'is_primary_data', 'cell_type_unknown',
#        'tissue_coarse_ontology_id', 'tissue_coarse',
#        'tissue_name_ont_coarsename_coarseont',
#        'coarse_development_stage_ontology_id', 'coarse_development_stage'],
#       dtype='object')

# %%
dfs = [donor_cell_type_df, num_cell_df, tissue_df, development_df, disease_df, sex_df]
df = pd.concat(dfs, axis=1)
print(df.shape)

df.reset_index()
#df.to_pickle("../data/pseudobulk/cell_metadata_coarsened.pkl")
# Out:
# (7305, 12)
#                                 dataset_id    donor_id  n_unique_cell_types  \
# 0     00476f9f-ebc1-4b72-b541-32f912ce36ea  H19.30.001                   11
# 1     01209dce-3575-4bed-b1df-129f57fbc031      Donor1                    6
# 2     01209dce-3575-4bed-b1df-129f57fbc031      Donor2                    6
# 3     01209dce-3575-4bed-b1df-129f57fbc031      DonorA                    4
# 4     01209dce-3575-4bed-b1df-129f57fbc031      DonorB                    4
# ...                                    ...         ...                  ...
# 7300  fe4b89d5-461e-440c-a5a8-621b37b122c0      195045                    8
# 7301  fe4b89d5-461e-440c-a5a8-621b37b122c0      199129                    8
# 7302  ff7d15fa-f4b6-4a0e-992e-fd0c9d088ded  H18.30.002                    9
# 7303  ff7d15fa-f4b6-4a0e-992e-fd0c9d088ded  H19.30.001                    8
# 7304  ff7d15fa-f4b6-4a0e-992e-fd0c9d088ded  H19.30.002                   10
#
#       cell_type_unknown_fraction  n_cells  \
# 0                            0.0    10099
# 1                            0.0    16185
# 2                            0.0    18066
# 3                            0.0     9193
# 4                            0.0     8432
# ...                          ...      ...
# 7300                         0.0     1864
# 7301                         0.0     1101
# 7302                         0.0     5728
# 7303                         0.0     9766
# 7304                         0.0    12557
#
#                    tissue_name_ont_coarsename_coarseont  n_tissues  \
# 0     [(hypothalamus, UBERON:0001898, brain, UBERON_...          1
# 1     [(lower lobe of left lung, UBERON:0008953, lun...          3
# 2     [(lower lobe of left lung, UBERON:0008953, lun...          3
# 3     [(venous blood, UBERON:0013756, blood, UBERON_...          1
# 4     [(venous blood, UBERON:0013756, blood, UBERON_...          1
# ...                                                 ...        ...
# 7300  [(ileal epithelium, UBERON:0008345, intestine,...          2
# 7301  [(ileum, UBERON:0002116, intestine, UBERON_000...          1
# 7302  [(cerebral cortex, UBERON:0000956, brain, UBER...          1
# 7303  [(cerebral cortex, UBERON:0000956, brain, UBER...          1
# 7304  [(cerebral cortex, UBERON:0000956, brain, UBER...          1
#
#                development_stage development_stage_ontology_term_id  \
# 0        42-year-old human stage                     HsapDv:0000136
# 1        65-year-old human stage                     HsapDv:0000159
# 2        52-year-old human stage                     HsapDv:0000146
# 3                        unknown                            unknown
# 4                        unknown                            unknown
# ...                          ...                                ...
# 7300  seventh decade human stage                     HsapDv:0000241
# 7301   eighth decade human stage                     HsapDv:0000242
# 7302     50-year-old human stage                     HsapDv:0000144
# 7303     42-year-old human stage                     HsapDv:0000136
# 7304     29-year-old human stage                     HsapDv:0000123
#
#      coarse_development_stage coarse_development_stage_ontology_id  \
# 0           middle aged stage                       HsapDv_0000267
# 1        60-79 year-old stage                       HsapDv_0000272
# 2           middle aged stage                       HsapDv_0000267
# 3                         NaN                                  NaN
# 4                         NaN                                  NaN
# ...                       ...                                  ...
# 7300     60-79 year-old stage                       HsapDv_0000272
# 7301     60-79 year-old stage                       HsapDv_0000272
# 7302        middle aged stage                       HsapDv_0000267
# 7303        middle aged stage                       HsapDv_0000267
# 7304        young adult stage                       HsapDv_0000266
#
#             disease disease_ontology_term_id     sex
# 0            normal             PATO:0000461    male
# 1            normal             PATO:0000461    male
# 2            normal             PATO:0000461    male
# 3            normal             PATO:0000461    male
# 4            normal             PATO:0000461    male
# ...             ...                      ...     ...
# 7300  Crohn disease            MONDO:0005011  female
# 7301         normal             PATO:0000461    male
# 7302         normal             PATO:0000461    male
# 7303         normal             PATO:0000461    male
# 7304         normal             PATO:0000461    male
#
# [7305 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['n_unique_cell_types', 'cell_type_unknown_fraction', 'n_cells',
#        'tissue_name_ont_coarsename_coarseont', 'n_tissues',
#        'development_stage', 'development_stage_ontology_term_id',
#        'coarse_development_stage', 'coarse_development_stage_ontology_id',
#        'disease', 'disease_ontology_term_id', 'sex'],
#       dtype='object')
